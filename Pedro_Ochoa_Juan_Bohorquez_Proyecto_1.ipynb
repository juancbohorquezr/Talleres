# %% [markdown]
# # Proyecto Primer Corte

# %% [markdown]
# La base de Datos fue extraida de: https://datos.bancomundial.org/tema/desarrollo-social?view=chart
# El proposito de la base es presentar el desarrollo social que tiene el mundo, por medio de visualizaciones que nos permitan identificar y comparar la evolucion general de diferentes paises.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
import matplotlib.pyplot as plt
import altair as alt
from vega_datasets import data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8792/2658197725.py in <module>
#       4 import matplotlib as plt
#       5 import matplotlib.pyplot as plt
# ----> 6 import altair as alt
#       7 from vega_datasets import data
#
# ModuleNotFoundError: No module named 'altair'

# %%
df_proyecto = pd.read_csv("C:/Users/fabia/Downloads/DatosProyectoVisualizacion.csv", 
                 sep = ',',
                )

# %%
df_proyecto.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1        Aruba          ABW
# 2        Aruba          ABW
# 3        Aruba          ABW
# 4        Aruba          ABW
#
#                                       Indicator Name     Indicator Code  \
# 0         Esperanza de vida al nacer, varones (años)  SP.DYN.LE00.MA.IN
# 1         Esperanza de vida al nacer, mujeres (años)  SP.DYN.LE00.FE.IN
# 2  Tasa de fertilidad en adolescentes (nacimiento...        SP.ADO.TFRT
# 3  Población de refugiados por país o territorio ...     SM.POP.REFG.OR
# 4  Población de refugiados por país o territorio ...        SM.POP.REFG
#
#        1960      1961    1962     1963     1964     1965  ...    2011    2012  \
# 0   64.0840   64.4290  64.747  65.0530  65.3560  65.6600  ...  72.654  72.792
# 1   67.1290   67.6250  68.065  68.4580  68.8170  69.1650  ...  77.561  77.695
# 2  106.2062  102.8116  99.417  94.4542  89.4914  84.5286  ...  29.582  28.512
# ...

# %%
df_col = df_proyecto[1530:1564]

# %% [markdown]
# En esta parte filtramos la base de datos para proceder a la actividad con el pais de Colombia.

# %%
df_col
# Out:
#      Country Name Country Code  \
# 1530     Colombia          COL
# 1531     Colombia          COL
# 1532     Colombia          COL
# 1533     Colombia          COL
# 1534     Colombia          COL
# 1535     Colombia          COL
# 1536     Colombia          COL
# 1537     Colombia          COL
# 1538     Colombia          COL
# 1539     Colombia          COL
# 1540     Colombia          COL
# 1541     Colombia          COL
# 1542     Colombia          COL
# 1543     Colombia          COL
# 1544     Colombia          COL
# 1545     Colombia          COL
# 1546     Colombia          COL
# 1547     Colombia          COL
# 1548     Colombia          COL
# 1549     Colombia          COL
# 1550     Colombia          COL
# 1551     Colombia          COL
# 1552     Colombia          COL
# 1553     Colombia          COL
# 1554     Colombia          COL
# 1555     Colombia          COL
# 1556     Colombia          COL
# 1557     Colombia          COL
# 1558     Colombia          COL
# ...

# %% [markdown]
# # Grafica de Barras

# %%
df_proporciones = df_col.drop(range(1530,1559),axis = 0)

# %% [markdown]
# Para graficar un Barplot usamos las proporciones de los siguientes indicadores, del año de 2011.

# %%
sns.barplot(data = df_proporciones ,
            x =  "2011" ,
            y =  "Indicator Name" ,
            ci = "None")
# Out:
# <AxesSubplot:xlabel='2011', ylabel='Indicator Name'>

# %% [markdown]
# # Matriz de Dispersion

# %%
df_trabajo = df_col.iloc[[8,11,25]]

# %% [markdown]
# Filtramos tasas de la poblacion Mujeres y la comparamos mediante una matriz de dispersion.

# %%
df_trabfil = df_trabajo.drop(["Country Name","Country Code","Indicator Code","Indicator Name"], axis = 1)

# %%
sns.pairplot(df_trabfil.transpose(), diag_kind="hist",palette = "winter")

# %% [markdown]
# Donde:                                                                                                                            1555 = Tasa de Empleo Vulnerable, mejeres (%),
#        1538 = Tasa de Poblacion activa, Mujeres (%),
#        1541 = Tasa de Participacion en la Fuerza Laboral, Mujeres (%),
#        1555 = empleo vulnerable, Mujeres (%).

# %% [markdown]
# # Mapa de Calor

# %%
df_refugiados = df_col.iloc[[3]]

# %% [markdown]
# Se filtra de la base la poblacion de refugiados de origen y se procede a hacer un mapa de calor donde el eje x son los años

# %%
df_refil = df_refugiados.drop(["Country Name","Country Code","Indicator Code","Indicator Name"], axis = 1)

# %%
df_refil2 = df_refil.iloc[:,51:62]

# %%
df_refil2
# Out:
#           2011      2012      2013      2014      2015      2016      2017  \
# 1533  395950.0  394112.0  396711.0  360291.0  340116.0  311059.0  191635.0
#
#           2018      2019      2020
# 1533  138583.0  189254.0  189889.0

# %%
ax = sns.heatmap(df_refil2)

# %% [markdown]
# donde: 1533 = Poblacion refugiada de origen.

# %%
df_refugiados2 = df_col.iloc[[4]]

# %% [markdown]
# Se filtra de la base la poblacion de refugiados de asilo y se procede a hacer un mapa de calor donde el eje x son los años.

# %%
df_refil2 = df_refugiados2.drop(["Country Name","Country Code","Indicator Code","Indicator Name"], axis = 1)

# %%
df_refil3 = df_refil2.iloc[:,51:62]

# %%
df_refil3
# Out:
#        2011   2012   2013   2014   2015   2016   2017   2018   2019   2020
# 1534  208.0  204.0  207.0  198.0  212.0  241.0  260.0  294.0  634.0  997.0

# %%
ax = sns.heatmap(df_refil3)

# %% [markdown]
# donde: 1534 = Poblacion refuigiada de asilo.

# %% [markdown]
# # Grafico de dispersion

# %%
df_esperanza = df_col.iloc[[0,1]]

# %% [markdown]
# Se filtra el indicador de esperanza de vida tanto de hombres como de mujeres, para saber que tanto  se dispersan los datos.

# %%
Se filtra de la base el indicador de esperanza de vida

# %%
df_espefil = df_esperanza.drop(["Country Name","Country Code","Indicator Code","Indicator Name"], axis = 1)

# %%
sns.scatterplot(data=df_espefil.transpose(),  x=1530, y=1531)
# Out:
# <AxesSubplot:xlabel='1530', ylabel='1531'>

# %% [markdown]
# Donde: 1531: Esperanza de vida, Mujeres.
#        1530: Esperanza de vida, Hombres.
